# %% [markdown]
# <a href="https://colab.research.google.com/github/MalVaroTor/MalVaroTor/blob/main/TCC_4_POT_ENERGIA_1_CICLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTANDO AS BIBLIOTECAS E LENDO O ARQUIVO EM EXCEL.**
#
# ---
#
# O NOME DO ARQUIVO VAI TER O NOME DE 'db', DE DATABASE.

# %%
# IMPORTANDO BIBLIOTECA PARA DADOS.
import pandas as pd

# IMPORTANDO BIBLIOTECA PARA GRÁFICOS.
import matplotlib.pyplot as plt

# IMPOTANDO BIBLIOTECA PARA TRABALHAR COM NÚMEROS.
import numpy as np

# IMPOTANDO BIBLIOTECA PARA TRABALHAR COM DATAS EM GRÁFICOS.
import matplotlib.dates as mdates

# IMPOTANDO BIBLIOTECA PARA CÁLCULOS ESTATÍSTICOS.
import statistics

# LENDO O ARQUIVO NO DRIVE.
db = pd.read_excel('/content/drive/MyDrive/TCC/db_dados/all_dados_I_V_T.xlsx')

# TRANSFORMANDO A COLUNA 'Data' DE FROMATO OBJECT PARA DATETIME.
db['Data'] = pd.to_datetime(db['Data'])

# TRANSFORMANDO A COLUNA DATA NO FORMATO 'DD/MM/AAA'.
db['Data'] = db['Data'].dt.strftime('%d/%m/%Y')

# APRESENTANDO VISUALMENTE A TABELA.
display(db)
# Out:
# <ipython-input-43-6285cf01b420>:20: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   db['Data'] = pd.to_datetime(db['Data'])
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 0     2023-01-17 09:53:15.000  17/01/2023  09:53:15                   28.1
# 1     2023-01-17 09:53:30.000  17/01/2023  09:53:30                   28.2
# 2     2023-01-17 09:53:45.000  17/01/2023  09:53:45                   28.2
# 3     2023-01-17 09:54:00.000  17/01/2023  09:54:00                   28.2
# 4     2023-01-17 09:54:15.000  17/01/2023  09:54:15                   28.2
# ...                       ...         ...       ...                    ...
# 58106 2024-02-29 12:00:23.826  29/02/2024  12:00:24                   31.7
# 58107 2024-02-29 12:00:38.826  29/02/2024  12:00:39                   32.9
# 58108 2024-02-29 12:00:53.826  29/02/2024  12:00:54                   33.5
# 58109 2024-02-29 12:01:08.826  29/02/2024  12:01:09                   33.5
# 58110 2024-02-29 12:01:23.826  29/02/2024  12:01:24                   33.5
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 0                           28.9                       28.8             0.1
# 1                           28.9                       28.8             0.1
# 2                           29.0                       28.8             0.1
# 3                           29.0                       28.9             0.1
# 4                           29.0                       28.9             0.1
# ...                          ...                        ...             ...
# 58106                       41.2                       40.4             0.2
# 58107                       41.0                       40.2             0.2
# 58108                       40.7                       40.1             0.3
# 58109                       40.7                       39.9             0.2
# 58110                       40.3                       39.8             0.2
#
#        Tensao_A_[V]  Temperatura_in_B_[ºC]  Temperatura_out_O2_B_[ºC]  \
# 0               0.0                   30.7                       29.3
# 1               0.0                   30.7                       29.3
# 2               0.0                   30.7                       29.3
# 3               0.0                   30.8                       29.3
# 4               0.0                   30.8                       29.3
# ...             ...                    ...                        ...
# 58106           0.5                   33.6                       41.6
# 58107           0.5                   33.4                       41.7
# 58108           0.4                   33.5                       41.7
# 58109           0.4                   33.8                       41.7
# 58110           0.4                   33.7                       41.5
#
#        Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  Tensao_B_[V]  PowerSet_[%]
# 0                           28.8             0.0           0.0            30
# 1                           28.8             0.0           0.0            30
# 2                           28.8             0.0           0.0            30
# 3                           28.9             0.0           0.0            30
# 4                           28.9             0.0           0.0            30
# ...                          ...             ...           ...           ...
# 58106                       40.4             3.6           0.0            50
# 58107                       40.2             3.6           0.0            50
# 58108                       40.1             3.6           0.0            50
# 58109                       39.9             3.6           0.0            30
# 58110                       39.8             3.6           0.0            30
#
# [58111 rows x 14 columns]

# %% [markdown]
# # **MOSTRANDO OS TIPOS DE DADOS DO 'db'.**
#
# ---

# %%
# TRAZENDO OS TIPOS DE DADOS DA TABELA.
tipos_dados = db.dtypes

# MOSTRANDO/APRESENTANDO OS RESULTADOS.
print(tipos_dados)
# Out:
# Data/Hora                    datetime64[ns]
# Data                                 object
# Hora                                 object
# Temperatura_in_A_[ºC]               float64
# Temperatura_out_O2_A_[ºC]           float64
# Temperatura_out_H2_A_[ºC]           float64
# Corrente_A_[A]                      float64
# Tensao_A_[V]                        float64
# Temperatura_in_B_[ºC]               float64
# Temperatura_out_O2_B_[ºC]           float64
# Temperatura_out_H2_B_[ºC]           float64
# Corrente_B_[A]                      float64
# Tensao_B_[V]                        float64
# PowerSet_[%]                          int64
# dtype: object

# %% [markdown]
# FILTRANDO A TABELA PARA APENAS 1 DIA EM ESPECÍFICO. O DB DO DIA SERÁ CHAMADO 'db_data_estudo'.

# %%
# FILTRANDO OS DADOS PARA A DATA ESPECÍFICA.
db_data_estudo = input('Digite a data de operação: ')

var_data_estudo = db_data_estudo
var_data_estudo = pd.to_datetime(var_data_estudo)
var_data_estudo = var_data_estudo.strftime('%d/%m/%Y')

'''
Datas  -  PowerSet de Produção
2023-01-17 - 70
2023-01-18 - 70
2023-01-24 - 70
2023-01-26 - 70
2023-01-31 - 70
2023-02-02 - 70
2023-02-07 - 70
2023-02-09 - 70
2023-02-14 - 80
2023-02-16 - 80
2023-02-23 - 80
2023-03-01 - 80
2023-03-02 - 70
2023-03-07 - 80
2023-03-14 - 80
2023-03-15 - 80
2023-03-23 - 80
2023-03-28 - 80
2023-03-29 - 80
2023-03-29 - 80
2023-04-04 - 80
2023-04-05 - 80
2023-04-05 - 80
2023-04-11 - 80
2023-04-11 - 80
2023-04-12 - 80
2023-04-13 - 80
2023-04-13 - 80
2023-04-18 - 90
2023-04-18 - 80
2023-04-19 - 80
2023-04-20 - 80
2023-04-20 - 80
2023-04-26 - 70
2023-04-27 - 70
2023-04-27 - 70
2023-05-02 - 80
2023-05-03 - 80
2023-05-03 - 80
2023-05-04 - 80
2023-05-09 - 80
2023-05-09 - 80
2023-05-10 - 80
2023-05-10 - 90
2023-05-11 - 90
2023-05-11 - 90
2023-05-16 - 90
2023-05-16 - 90
2023-05-17 - 90
2023-05-17 - 90
2023-05-30 - 90
2023-05-31 - 90
2023-06-01 - 90
2023-06-06 - 90
2023-06-07 - 90
2023-06-15 - 70
2023-06-22 - 70
2023-06-28 - 70
2023-07-11 - 70
2023-07-13 - 70
2023-07-20 - 70
2023-07-25 - 70
2023-07-27 - 70
2023-08-03 - 70
2023-08-22 - 80
2023-08-24 - 70
2023-08-29 - 70
2023-08-31 - 70
2023-09-05 - 70
2023-09-14 - 70
2023-09-19 - 70
2023-09-21 - 70
2023-10-03 - 70
2023-10-05 - 70
2023-10-10 - 70
2023-10-17 - 70
2023-10-17 - 70
2023-10-18 - 70
2023-10-18 - 70
2023-10-19 - 70
2023-10-19 - 70
2023-10-20 - 70
2023-10-23 - 70
2023-10-23 - 70
2023-10-24 - 70
2023-10-24 - 70
2023-10-25 - 70
2023-10-25 - 70
2023-10-26 - 70
2023-10-26 - 70
2023-10-27 - 70
2023-11-07 - 70
2023-11-09 - 70
2023-11-14 - 70
2023-11-21 - 70
2023-12-07 - 70
2023-12-14 - 70
2023-12-26 - 70
2024-01-02 - 70
2024-01-11 - 70

'''

db_data_estudo = pd.to_datetime(db_data_estudo)
db_data_estudo = db[db['Data/Hora'].dt.date == pd.to_datetime(db_data_estudo).date()]

display(db_data_estudo)
# Out:
# Digite a data de operação: 2023-12-26
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55757 2023-12-26 09:22:02.834  26/12/2023  09:22:03                   26.0
# 55758 2023-12-26 09:22:17.834  26/12/2023  09:22:18                   26.0
# 55759 2023-12-26 09:22:32.834  26/12/2023  09:22:33                   26.0
# 55760 2023-12-26 09:22:47.834  26/12/2023  09:22:48                   26.0
# 55761 2023-12-26 09:23:02.834  26/12/2023  09:23:03                   26.0
# ...                       ...         ...       ...                    ...
# 56120 2023-12-26 10:52:47.834  26/12/2023  10:52:48                   35.7
# 56121 2023-12-26 10:53:02.834  26/12/2023  10:53:03                   35.7
# 56122 2023-12-26 10:53:17.834  26/12/2023  10:53:18                   35.7
# 56123 2023-12-26 10:53:32.834  26/12/2023  10:53:33                   35.7
# 56124 2023-12-26 10:53:47.834  26/12/2023  10:53:48                   35.7
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55757                       29.3                       26.1             0.2
# 55758                       27.7                       26.1             0.2
# 55759                       27.2                       26.1             0.1
# 55760                       26.3                       26.1             0.1
# 55761                       25.8                       26.1             0.2
# ...                          ...                        ...             ...
# 56120                       40.1                       39.1             0.2
# 56121                       39.9                       39.0             0.2
# 56122                       39.7                       38.8             0.2
# 56123                       39.4                       38.8             0.2
# 56124                       39.3                       38.7             0.2
#
#        Tensao_A_[V]  Temperatura_in_B_[ºC]  Temperatura_out_O2_B_[ºC]  \
# 55757           0.0                   28.1                       26.5
# 55758           0.0                   28.1                       26.5
# 55759           0.0                   28.1                       26.5
# 55760           0.0                   28.1                       26.5
# 55761           0.0                   28.2                       26.5
# ...             ...                    ...                        ...
# 56120           0.5                   37.5                       41.1
# 56121           0.4                   37.4                       41.1
# 56122           0.4                   37.3                       41.0
# 56123           0.4                   37.3                       40.9
# 56124           0.4                   37.3                       40.8
#
#        Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  Tensao_B_[V]  PowerSet_[%]
# 55757                       26.1             0.0           0.0            30
# 55758                       26.1             0.0           0.0            30
# 55759                       26.1             0.0           0.0            30
# 55760                       26.1             0.0           0.0            30
# 55761                       26.1             0.0           0.0            30
# ...                          ...             ...           ...           ...
# 56120                       39.1             1.5           0.0            30
# 56121                       39.0             1.5           0.0            30
# 56122                       38.8             1.5           0.0            30
# 56123                       38.8             1.5           0.0            30
# 56124                       38.7             1.5           0.0            30
#
# [368 rows x 14 columns]

# %% [markdown]
# # **CRIANDO E FORMATANDO O GRÁFICO DE CORRENTES A E B DO DIA DE ESTUDO.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_data_estudo['Data/Hora'], db_data_estudo['Corrente_A_[A]'], label='Corrente A')
plt.plot(db_data_estudo['Data/Hora'], db_data_estudo['Corrente_B_[A]'], label='Corrente B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Correntes [A]')

# ADICIONANDO O TÍTULO.

plt.title(f'Correntes A e B em [A] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# %% [markdown]
# # **FILTRANDO OS DADOS PELO INTERVALO DE POWERSET DE PRODUÇÃO DE H2.**
#
# ---

# %%
ps_entrada = input('Digite o PowerSet de produção de H2: ')

ps_entrada = float(ps_entrada)

db_ps_estudo = db_data_estudo.loc[db_data_estudo['PowerSet_[%]'] == ps_entrada]

# Exibindo o resultado
display(db_ps_estudo)
# Out:
# Digite o PowerSet de produção de H2: 70
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55910 2023-12-26 10:00:17.834  26/12/2023  10:00:18                   31.4
# 55911 2023-12-26 10:00:32.834  26/12/2023  10:00:33                   31.1
# 55912 2023-12-26 10:00:47.834  26/12/2023  10:00:48                   30.7
# 55913 2023-12-26 10:01:02.834  26/12/2023  10:01:03                   30.3
# 55914 2023-12-26 10:01:17.834  26/12/2023  10:01:18                   30.3
# ...                       ...         ...       ...                    ...
# 56050 2023-12-26 10:35:17.834  26/12/2023  10:35:18                   37.3
# 56051 2023-12-26 10:35:32.834  26/12/2023  10:35:33                   36.1
# 56052 2023-12-26 10:35:47.834  26/12/2023  10:35:48                   37.2
# 56053 2023-12-26 10:36:02.834  26/12/2023  10:36:03                   37.3
# 56054 2023-12-26 10:36:17.834  26/12/2023  10:36:18                   35.9
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55910                       34.9                       35.2            96.7
# 55911                       35.0                       35.5            93.0
# 55912                       35.7                       35.7           105.4
# 55913                       35.6                       36.0           101.3
# 55914                       36.0                       36.3           128.4
# ...                          ...                        ...             ...
# 56050                       46.9                       44.3           109.1
# 56051                       46.6                       44.0           115.1
# 56052                       47.1                       44.2           132.8
# 56053                       47.1                       44.4           130.0
# 56054                       47.0                       44.4           120.2
#
#        Tensao_A_[V]  Temperatura_in_B_[ºC]  Temperatura_out_O2_B_[ºC]  \
# 55910         129.4                   34.1                       35.8
# 55911         130.7                   33.6                       35.9
# 55912         130.7                   33.3                       36.2
# 55913         130.8                   33.0                       36.5
# 55914         130.8                   32.9                       36.6
# ...             ...                    ...                        ...
# 56050         130.0                   40.0                       45.2
# 56051         129.9                   39.0                       45.3
# 56052         129.9                   39.8                       45.4
# 56053         129.9                   40.0                       45.5
# 56054         129.9                   38.6                       45.6
#
#        Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  Tensao_B_[V]  PowerSet_[%]
# 55910                       35.2           104.4         120.6            70
# 55911                       35.5           114.3         122.6            70
# 55912                       35.7           118.2         122.6            70
# 55913                       36.0           106.1         122.7            70
# 55914                       36.3           123.0         122.9            70
# ...                          ...             ...           ...           ...
# 56050                       44.3           111.0         121.4            70
# 56051                       44.0           103.2         121.3            70
# 56052                       44.2           133.3         121.3            70
# 56053                       44.4           118.4         121.4            70
# 56054                       44.4            94.4         121.3            70
#
# [145 rows x 14 columns]

# %% [markdown]
# # **GERANDO GRÁFICO DE CORRENTES A E B ONDE SÓ TEM O POWERSET DESEJADO.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Corrente_A_[A]'], label='Corrente A')
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Corrente_B_[A]'], label='Corrente B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Correntes [A]')

# ADICIONANDO O TÍTULO.
plt.title(f'Correntes A e B em [A] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# %% [markdown]
# # **CALCULANDO AS POTÊNCIAS A E B E ADICIONANDO AO DB.**
#
# ---

# %%
# TRAZENDO O ÍNDICE DA COLUNA 'Tensao_A_[V]'.
indice_tensao_A = db_ps_estudo.columns.get_loc('Tensao_A_[V]')

# INSERINDO A COLUNA 'Potencia_A_[kW]' DEPOIS DA COLUNA 'Tensao_A_[V]'.
db_ps_estudo.insert(indice_tensao_A + 1, 'Potencia_A_[kW]', db_ps_estudo['Corrente_A_[A]'] * db_ps_estudo['Tensao_A_[V]'] / 1000)

# TRAZENDO O ÍNDICE DA COLUNA 'Tensao_B_[V]'.
indice_tensao_B = db_ps_estudo.columns.get_loc('Tensao_B_[V]')

# INSERINDO A COLUNA 'Potencia_B_[kW]' DEPOIS DA COLUNA 'Tensao_B_[V]'.
db_ps_estudo.insert(indice_tensao_B + 1, 'Potencia_B_[kW]', db_ps_estudo['Corrente_B_[A]'] * db_ps_estudo['Tensao_B_[V]'] / 1000)

display(db_ps_estudo)
# Out:
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55910 2023-12-26 10:00:17.834  26/12/2023  10:00:18                   31.4
# 55911 2023-12-26 10:00:32.834  26/12/2023  10:00:33                   31.1
# 55912 2023-12-26 10:00:47.834  26/12/2023  10:00:48                   30.7
# 55913 2023-12-26 10:01:02.834  26/12/2023  10:01:03                   30.3
# 55914 2023-12-26 10:01:17.834  26/12/2023  10:01:18                   30.3
# ...                       ...         ...       ...                    ...
# 56050 2023-12-26 10:35:17.834  26/12/2023  10:35:18                   37.3
# 56051 2023-12-26 10:35:32.834  26/12/2023  10:35:33                   36.1
# 56052 2023-12-26 10:35:47.834  26/12/2023  10:35:48                   37.2
# 56053 2023-12-26 10:36:02.834  26/12/2023  10:36:03                   37.3
# 56054 2023-12-26 10:36:17.834  26/12/2023  10:36:18                   35.9
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55910                       34.9                       35.2            96.7
# 55911                       35.0                       35.5            93.0
# 55912                       35.7                       35.7           105.4
# 55913                       35.6                       36.0           101.3
# 55914                       36.0                       36.3           128.4
# ...                          ...                        ...             ...
# 56050                       46.9                       44.3           109.1
# 56051                       46.6                       44.0           115.1
# 56052                       47.1                       44.2           132.8
# 56053                       47.1                       44.4           130.0
# 56054                       47.0                       44.4           120.2
#
#        Tensao_A_[V]  Potencia_A_[kW]  Temperatura_in_B_[ºC]  \
# 55910         129.4         12.51298                   34.1
# 55911         130.7         12.15510                   33.6
# 55912         130.7         13.77578                   33.3
# 55913         130.8         13.25004                   33.0
# 55914         130.8         16.79472                   32.9
# ...             ...              ...                    ...
# 56050         130.0         14.18300                   40.0
# 56051         129.9         14.95149                   39.0
# 56052         129.9         17.25072                   39.8
# 56053         129.9         16.88700                   40.0
# 56054         129.9         15.61398                   38.6
#
#        Temperatura_out_O2_B_[ºC]  Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  \
# 55910                       35.8                       35.2           104.4
# 55911                       35.9                       35.5           114.3
# 55912                       36.2                       35.7           118.2
# 55913                       36.5                       36.0           106.1
# 55914                       36.6                       36.3           123.0
# ...                          ...                        ...             ...
# 56050                       45.2                       44.3           111.0
# 56051                       45.3                       44.0           103.2
# 56052                       45.4                       44.2           133.3
# 56053                       45.5                       44.4           118.4
# 56054                       45.6                       44.4            94.4
#
#        Tensao_B_[V]  Potencia_B_[kW]  PowerSet_[%]
# 55910         120.6         12.59064            70
# 55911         122.6         14.01318            70
# 55912         122.6         14.49132            70
# 55913         122.7         13.01847            70
# 55914         122.9         15.11670            70
# ...             ...              ...           ...
# 56050         121.4         13.47540            70
# 56051         121.3         12.51816            70
# 56052         121.3         16.16929            70
# 56053         121.4         14.37376            70
# 56054         121.3         11.45072            70
#
# [145 rows x 16 columns]

# %% [markdown]
# # **GERANDO GRÁFICO DE POTÊNCIAS A E B.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Potencia_A_[kW]'], label='Potência A')
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Potencia_B_[kW]'], label='Potência B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Potências [kW]')

# ADICIONANDO O TÍTULO.
plt.title(f'Potências A e B em [kW] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# %% [markdown]
# # **CRIANDO A COLUNA "Hora_Decimal."**
#
# ---

# %%
# CRIANDO A COLUNA 'Hora_decimal'.
db_ps_estudo['Hora_decimal'] = db_ps_estudo['Data/Hora'].dt.hour + db_ps_estudo['Data/Hora'].dt.minute / 60 + db_ps_estudo['Data/Hora'].dt.second / 3600

display(db_ps_estudo)
# Out:
# <ipython-input-51-d96babe9a0b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_ps_estudo['Hora_decimal'] = db_ps_estudo['Data/Hora'].dt.hour + db_ps_estudo['Data/Hora'].dt.minute / 60 + db_ps_estudo['Data/Hora'].dt.second / 3600
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55910 2023-12-26 10:00:17.834  26/12/2023  10:00:18                   31.4
# 55911 2023-12-26 10:00:32.834  26/12/2023  10:00:33                   31.1
# 55912 2023-12-26 10:00:47.834  26/12/2023  10:00:48                   30.7
# 55913 2023-12-26 10:01:02.834  26/12/2023  10:01:03                   30.3
# 55914 2023-12-26 10:01:17.834  26/12/2023  10:01:18                   30.3
# ...                       ...         ...       ...                    ...
# 56050 2023-12-26 10:35:17.834  26/12/2023  10:35:18                   37.3
# 56051 2023-12-26 10:35:32.834  26/12/2023  10:35:33                   36.1
# 56052 2023-12-26 10:35:47.834  26/12/2023  10:35:48                   37.2
# 56053 2023-12-26 10:36:02.834  26/12/2023  10:36:03                   37.3
# 56054 2023-12-26 10:36:17.834  26/12/2023  10:36:18                   35.9
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55910                       34.9                       35.2            96.7
# 55911                       35.0                       35.5            93.0
# 55912                       35.7                       35.7           105.4
# 55913                       35.6                       36.0           101.3
# 55914                       36.0                       36.3           128.4
# ...                          ...                        ...             ...
# 56050                       46.9                       44.3           109.1
# 56051                       46.6                       44.0           115.1
# 56052                       47.1                       44.2           132.8
# 56053                       47.1                       44.4           130.0
# 56054                       47.0                       44.4           120.2
#
#        Tensao_A_[V]  Potencia_A_[kW]  Temperatura_in_B_[ºC]  \
# 55910         129.4         12.51298                   34.1
# 55911         130.7         12.15510                   33.6
# 55912         130.7         13.77578                   33.3
# 55913         130.8         13.25004                   33.0
# 55914         130.8         16.79472                   32.9
# ...             ...              ...                    ...
# 56050         130.0         14.18300                   40.0
# 56051         129.9         14.95149                   39.0
# 56052         129.9         17.25072                   39.8
# 56053         129.9         16.88700                   40.0
# 56054         129.9         15.61398                   38.6
#
#        Temperatura_out_O2_B_[ºC]  Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  \
# 55910                       35.8                       35.2           104.4
# 55911                       35.9                       35.5           114.3
# 55912                       36.2                       35.7           118.2
# 55913                       36.5                       36.0           106.1
# 55914                       36.6                       36.3           123.0
# ...                          ...                        ...             ...
# 56050                       45.2                       44.3           111.0
# 56051                       45.3                       44.0           103.2
# 56052                       45.4                       44.2           133.3
# 56053                       45.5                       44.4           118.4
# 56054                       45.6                       44.4            94.4
#
#        Tensao_B_[V]  Potencia_B_[kW]  PowerSet_[%]  Hora_decimal
# 55910         120.6         12.59064            70     10.004722
# 55911         122.6         14.01318            70     10.008889
# 55912         122.6         14.49132            70     10.013056
# 55913         122.7         13.01847            70     10.017222
# 55914         122.9         15.11670            70     10.021389
# ...             ...              ...           ...           ...
# 56050         121.4         13.47540            70     10.588056
# 56051         121.3         12.51816            70     10.592222
# 56052         121.3         16.16929            70     10.596389
# 56053         121.4         14.37376            70     10.600556
# 56054         121.3         11.45072            70     10.604722
#
# [145 rows x 17 columns]

# %% [markdown]
# # **CALCULANDO A INTEGRAL DO GRÁFICO DE POTÊNCIA EM RELAÇÃO AO TEMPO PARA DETERMINAR A ENERGIA.**
#
# ---

# %%
energia_a = np.trapz(db_ps_estudo['Potencia_A_[kW]'], x=db_ps_estudo['Hora_decimal'])
energia_a = round(energia_a, 3)

energia_b = np.trapz(db_ps_estudo['Potencia_B_[kW]'], x=db_ps_estudo['Hora_decimal'])
energia_b = round(energia_b, 3)

print(f"Quantidade de Energia do Eletrolisador A em [kWh] no dia {var_data_estudo}: ", energia_a)

print(f"Quantidade de Energia do Eletrolisador B em [kWh] no dia {var_data_estudo}: ", energia_b)
# Out:
# Quantidade de Energia do Eletrolisador A em [kWh] no dia 26/12/2023:  8.976
# Quantidade de Energia do Eletrolisador B em [kWh] no dia 26/12/2023:  8.553
