# %% [markdown]
# <a href="https://colab.research.google.com/github/MalVaroTor/MalVaroTor/blob/main/TCC_4_POT_ENERGIA_1_CICLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CÁLCULO DE ENERGIA PARA 1 CICLO DE OPERAÇÃO.**
#
# ---

# %% [markdown]
# # **PARTE 1**
#
# ---

# %%
#       >>>   IMPORTANDO AS BIBLIOTECAS E LENDO O ARQUIVO EM EXCEL.    <<<

# IMPORTANDO BIBLIOTECA PARA DADOS.
import pandas as pd

# IMPORTANDO BIBLIOTECA PARA GRÁFICOS.
import matplotlib.pyplot as plt

# IMPOTANDO BIBLIOTECA PARA TRABALHAR COM NÚMEROS.
import numpy as np

# IMPOTANDO BIBLIOTECA PARA TRABALHAR COM DATAS EM GRÁFICOS.
import matplotlib.dates as mdates

# IMPOTANDO BIBLIOTECA PARA CÁLCULOS ESTATÍSTICOS.
import statistics

# LENDO O ARQUIVO NO DRIVE.
db = pd.read_excel('/content/drive/MyDrive/TCC/db_dados/all_dados_I_V_T.xlsx')

# TRANSFORMANDO A COLUNA 'Data' DE FROMATO OBJECT PARA DATETIME.
db['Data'] = pd.to_datetime(db['Data'])

# TRANSFORMANDO A COLUNA DATA NO FORMATO 'DD/MM/AAA'.
db['Data'] = db['Data'].dt.strftime('%d/%m/%Y')

# APRESENTANDO VISUALMENTE A TABELA.
display(db)

# ------------------------------------------------------------------------------------------------------

#       >>>   MOSTRANDO OS TIPOS DE DADOS DO 'db'.    <<<

# TRAZENDO OS TIPOS DE DADOS DA TABELA.
tipos_dados = db.dtypes

# MOSTRANDO/APRESENTANDO OS RESULTADOS.
print(tipos_dados)

# ------------------------------------------------------------------------------------------------------

#       >>>   FILTRANDO A TABELA PARA APENAS 1 DIA EM ESPECÍFICO.    <<<


# FILTRANDO OS DADOS PARA A DATA ESPECÍFICA.
db_data_estudo = input('Digite a data de operação: ')

var_data_estudo = db_data_estudo
var_data_estudo = pd.to_datetime(var_data_estudo)
var_data_estudo = var_data_estudo.strftime('%d/%m/%Y')

'''
Datas  -  PowerSet de Produção
2023-01-17 - 70
2023-01-18 - 70
2023-01-24 - 70
2023-01-26 - 70
2023-01-31 - 70
2023-02-02 - 70
2023-02-07 - 70
2023-02-09 - 70
2023-02-14 - 80
2023-02-16 - 80
2023-02-23 - 80
2023-03-01 - 80
2023-03-02 - 70
2023-03-07 - 80
2023-03-14 - 80
2023-03-15 - 80
2023-03-23 - 80
2023-03-28 - 80
2023-03-29 - 80
2023-03-29 - 80
2023-04-04 - 80
2023-04-05 - 80
2023-04-05 - 80
2023-04-11 - 80
2023-04-11 - 80
2023-04-12 - 80
2023-04-13 - 80
2023-04-13 - 80
2023-04-18 - 90
2023-04-18 - 80
2023-04-19 - 80
2023-04-20 - 80
2023-04-20 - 80
2023-04-26 - 70
2023-04-27 - 70
2023-04-27 - 70
2023-05-02 - 80
2023-05-03 - 80
2023-05-03 - 80
2023-05-04 - 80
2023-05-09 - 80
2023-05-09 - 80
2023-05-10 - 80
2023-05-10 - 90
2023-05-11 - 90
2023-05-11 - 90
2023-05-16 - 90
2023-05-16 - 90
2023-05-17 - 90
2023-05-17 - 90
2023-05-30 - 90
2023-05-31 - 90
2023-06-01 - 90
2023-06-06 - 90
2023-06-07 - 90
2023-06-15 - 70
2023-06-22 - 70
2023-06-28 - 70
2023-07-11 - 70
2023-07-13 - 70
2023-07-20 - 70
2023-07-25 - 70
2023-07-27 - 70
2023-08-03 - 70
2023-08-22 - 80
2023-08-24 - 70
2023-08-29 - 70
2023-08-31 - 70
2023-09-05 - 70
2023-09-14 - 70
2023-09-19 - 70
2023-09-21 - 70
2023-10-03 - 70
2023-10-05 - 70
2023-10-10 - 70
2023-10-17 - 70
2023-10-17 - 70
2023-10-18 - 70
2023-10-18 - 70
2023-10-19 - 70
2023-10-19 - 70
2023-10-20 - 70
2023-10-23 - 70
2023-10-23 - 70
2023-10-24 - 70
2023-10-24 - 70
2023-10-25 - 70
2023-10-25 - 70
2023-10-26 - 70
2023-10-26 - 70
2023-10-27 - 70
2023-11-07 - 70
2023-11-09 - 70
2023-11-14 - 70
2023-11-21 - 70
2023-12-07 - 70
2023-12-14 - 70
2023-12-26 - 70
2024-01-02 - 70
2024-01-11 - 70

'''

db_data_estudo = pd.to_datetime(db_data_estudo)
db_data_estudo = db[db['Data/Hora'].dt.date == pd.to_datetime(db_data_estudo).date()]

display(db_data_estudo)

# ------------------------------------------------------------------------------------------------------

#       >>>   CRIANDO E FORMATANDO O GRÁFICO DE CORRENTES A E B DO DIA DE ESTUDO.    <<<

# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_data_estudo['Data/Hora'], db_data_estudo['Corrente_A_[A]'], label='Corrente A')
plt.plot(db_data_estudo['Data/Hora'], db_data_estudo['Corrente_B_[A]'], label='Corrente B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Correntes [A]')

# ADICIONANDO O TÍTULO.

plt.title(f'Correntes A e B em [A] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-4-c4029a52bb70>:22: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   db['Data'] = pd.to_datetime(db['Data'])
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 0     2023-01-17 09:53:15.000  17/01/2023  09:53:15                   28.1
# 1     2023-01-17 09:53:30.000  17/01/2023  09:53:30                   28.2
# 2     2023-01-17 09:53:45.000  17/01/2023  09:53:45                   28.2
# 3     2023-01-17 09:54:00.000  17/01/2023  09:54:00                   28.2
# 4     2023-01-17 09:54:15.000  17/01/2023  09:54:15                   28.2
# ...                       ...         ...       ...                    ...
# 58106 2024-02-29 12:00:23.826  29/02/2024  12:00:24                   31.7
# 58107 2024-02-29 12:00:38.826  29/02/2024  12:00:39                   32.9
# ...

# %% [markdown]
# # **PARTE 2**
#
# ---

# %%
#       >>>   FILTRANDO OS DADOS PELO INTERVALO DE POWERSET DE PRODUÇÃO DE H2.    <<<

ps_entrada = input('Digite o PowerSet de produção de H2: ')

ps_entrada = float(ps_entrada)

db_ps_estudo = db_data_estudo.loc[db_data_estudo['PowerSet_[%]'] >= ps_entrada]

display(db_ps_estudo)


# ------------------------------------------------------------------------------------------------------

#       >>>   GERANDO GRÁFICO DE CORRENTES A E B ONDE SÓ TEM O POWERSET DESEJADO.    <<<

# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Corrente_A_[A]'], label='Corrente A')
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Corrente_B_[A]'], label='Corrente B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Correntes [A]')

# ADICIONANDO O TÍTULO.
plt.title(f'Correntes A e B em [A] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# ------------------------------------------------------------------------------------------------------

#       >>>   CALCULANDO AS POTÊNCIAS A E B E ADICIONANDO AO DB.    <<<

# TRAZENDO O ÍNDICE DA COLUNA 'Tensao_A_[V]'.
indice_tensao_A = db_ps_estudo.columns.get_loc('Tensao_A_[V]')

# INSERINDO A COLUNA 'Potencia_A_[kW]' DEPOIS DA COLUNA 'Tensao_A_[V]'.
db_ps_estudo.insert(indice_tensao_A + 1, 'Potencia_A_[kW]', db_ps_estudo['Corrente_A_[A]'] * db_ps_estudo['Tensao_A_[V]'] / 1000)

# TRAZENDO O ÍNDICE DA COLUNA 'Tensao_B_[V]'.
indice_tensao_B = db_ps_estudo.columns.get_loc('Tensao_B_[V]')

# INSERINDO A COLUNA 'Potencia_B_[kW]' DEPOIS DA COLUNA 'Tensao_B_[V]'.
db_ps_estudo.insert(indice_tensao_B + 1, 'Potencia_B_[kW]', db_ps_estudo['Corrente_B_[A]'] * db_ps_estudo['Tensao_B_[V]'] / 1000)

display(db_ps_estudo)

# ------------------------------------------------------------------------------------------------------

#       >>>   GERANDO GRÁFICO DE POTÊNCIAS A E B.    <<<

# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Potencia_A_[kW]'], label='Potência A')
plt.plot(db_ps_estudo['Data/Hora'], db_ps_estudo['Potencia_B_[kW]'], label='Potência B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Potências [kW]')

# ADICIONANDO O TÍTULO.
plt.title(f'Potências A e B em [kW] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# ------------------------------------------------------------------------------------------------------

#       >>>   CRIANDO A COLUNA "Hora_Decimal".    <<<

db_ps_estudo['Hora_decimal'] = db_ps_estudo['Data/Hora'].dt.hour +                              \
                                    db_ps_estudo['Data/Hora'].dt.minute /                       \
                                            60 + db_ps_estudo['Data/Hora'].dt.second / 3600

display(db_ps_estudo)

# ------------------------------------------------------------------------------------------------------

#       >>>   CALCULANDO A INTEGRAL DO GRÁFICO DE POTÊNCIA EM RELAÇÃO AO TEMPO PARA DETERMINAR A ENERGIA.    <<<

energia_a = np.trapz(db_ps_estudo['Potencia_A_[kW]'], x=db_ps_estudo['Hora_decimal'])
energia_a = round(energia_a, 3)

energia_b = np.trapz(db_ps_estudo['Potencia_B_[kW]'], x=db_ps_estudo['Hora_decimal'])
energia_b = round(energia_b, 3)

print(f"Quantidade de Energia do Eletrolisador A em [kWh] no dia {var_data_estudo}: ", energia_a)

print(f"Quantidade de Energia do Eletrolisador B em [kWh] no dia {var_data_estudo}: ", energia_b)
# Out:
# Digite o PowerSet de produção de H2: 70
#               Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 457 2023-01-18 11:15:15  18/01/2023  11:15:15                   30.9
# 458 2023-01-18 11:15:30  18/01/2023  11:15:30                   31.0
# 459 2023-01-18 11:15:45  18/01/2023  11:15:45                   31.1
# 460 2023-01-18 11:16:00  18/01/2023  11:16:00                   31.1
# 461 2023-01-18 11:16:15  18/01/2023  11:16:15                   31.1
# ..                  ...         ...       ...                    ...
# 622 2023-01-18 11:56:30  18/01/2023  11:56:30                   37.8
# 623 2023-01-18 11:56:45  18/01/2023  11:56:45                   39.2
# 624 2023-01-18 11:57:00  18/01/2023  11:57:00                   39.2
# 625 2023-01-18 11:57:15  18/01/2023  11:57:15                   37.8
# 626 2023-01-18 11:57:30  18/01/2023  11:57:30                   39.3
#
#      Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# ...

# %% [markdown]
# # **LIMITANDO AGORA ALÉM DA DATA ESCOLHIDA, O TEMPO DE OPERAÇÃO TAMBÉM.**
#
# ---

# %%
#       >>>   LIMITANDO AGORA ALÉM DA DATA ESCOLHIDA, O TEMPO DE OPERAÇÃO TAMBÉM.    <<<

# Especificar o intervalo de horário
hora_inicio = input("Digite a hora inicial do PowerSet de produção no formato 'HH:MM:SS': ")
hora_fim = input("Digite a hora final do PowerSet de produção no formato 'HH:MM:SS': ")

# Filtrar os dados dentro do intervalo de horário
db_hr_estudo = db_ps_estudo[(db_ps_estudo['Data/Hora'].dt.time >= pd.to_datetime(hora_inicio).time()) &
                                                (db_ps_estudo['Data/Hora'].dt.time <= pd.to_datetime(hora_fim).time())]

display(db_hr_estudo)

# ------------------------------------------------------------------------------------------------------

#       >>>   CALCULANDO AS POTÊNCIAS A E B E ADICIONANDO AO DB.    <<<

# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_hr_estudo['Data/Hora'], db_hr_estudo['Corrente_A_[A]'], label='Corrente A')
plt.plot(db_hr_estudo['Data/Hora'], db_hr_estudo['Corrente_B_[A]'], label='Corrente B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Correntes [A]')

# ADICIONANDO O TÍTULO.

plt.title(f'Correntes A e B em [A] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# ------------------------------------------------------------------------------------------------------

#       >>>   GERANDO GRÁFICO DE POTÊNCIAS A E B.    <<<

# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_hr_estudo['Data/Hora'], db_hr_estudo['Potencia_A_[kW]'], label='Potência A')
plt.plot(db_hr_estudo['Data/Hora'], db_hr_estudo['Potencia_B_[kW]'], label='Potência B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')
plt.ylabel('Potências [kW]')

# ADICIONANDO O TÍTULO.
plt.title(f'Potências A e B em [kW] ao longo do tempo no dia {var_data_estudo}')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()
plt.show()

# ------------------------------------------------------------------------------------------------------

#       >>>   CALCULANDO AS ENERGIAS DE A E DE B REFERRENTE AOS HORÁRIOS PRÉ ESTABELECIDOS.    <<<

energia_a_hr = np.trapz(db_hr_estudo['Potencia_A_[kW]'], x=db_hr_estudo['Hora_decimal'])
energia_a_hr = round(energia_a_hr, 3)

energia_b_hr = np.trapz(db_hr_estudo['Potencia_B_[kW]'], x=db_hr_estudo['Hora_decimal'])
energia_b_hr = round(energia_b_hr, 3)

print(f"Quantidade de Energia do Eletrolisador A em [kWh] no dia {var_data_estudo}: ", energia_a_hr)

print(f"Quantidade de Energia do Eletrolisador B em [kWh] no dia {var_data_estudo}: ", energia_b_hr)

energia_total = energia_a_hr + energia_b_hr

print(f"Quantidade Total de Energia em [kWh] no dia {var_data_estudo}: ", energia_total)
# Out:
# Digite a hora inicial do PowerSet de produção no formato 'HH:MM:SS': 11:15:15
# Digite a hora final do PowerSet de produção no formato 'HH:MM:SS': 11:57:30
#               Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 457 2023-01-18 11:15:15  18/01/2023  11:15:15                   30.9
# 458 2023-01-18 11:15:30  18/01/2023  11:15:30                   31.0
# 459 2023-01-18 11:15:45  18/01/2023  11:15:45                   31.1
# 460 2023-01-18 11:16:00  18/01/2023  11:16:00                   31.1
# 461 2023-01-18 11:16:15  18/01/2023  11:16:15                   31.1
# ..                  ...         ...       ...                    ...
# 622 2023-01-18 11:56:30  18/01/2023  11:56:30                   37.8
# 623 2023-01-18 11:56:45  18/01/2023  11:56:45                   39.2
# 624 2023-01-18 11:57:00  18/01/2023  11:57:00                   39.2
# 625 2023-01-18 11:57:15  18/01/2023  11:57:15                   37.8
# ...
