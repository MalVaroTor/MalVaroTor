# %% [markdown]
# <a href="https://colab.research.google.com/github/MalVaroTor/MalVaroTor/blob/main/TCC_1_Teste_Energia_Grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORTANDO AS BIBLIOTECAS E LENDO O ARQUIVO EM EXCEL.**
#
#
# ---
#
# O NOME DO ARQUIVO VAI TER O NOME DE 'db', DE DATABASE.

# %%
# IMPORTANDO BIBLIOTECA PARA DADOS.
import pandas as pd

# IMPORTANDO BIBLIOTECA PARA GRÁFICOS.
import matplotlib.pyplot as plt

# IMPOTANDO BIBLIOTECA PARA TRABALHAR COM NÚMEROS.
import numpy as np

# LENDO O ARQUIVO NO DRIVE.
db = pd.read_excel('/content/drive/MyDrive/TCC/db_dados/dados_IVT.xlsx')

# APRESENTANDO VISUALMENTE A TABELA.
display(db)
# Out:
#                 Data/Hora                 Data      Hora  \
# 0     2023-01-17 09:53:15  2023-01-17 00:00:00  09:53:15
# 1     2023-01-17 09:53:30  2023-01-17 00:00:00  09:53:30
# 2     2023-01-17 09:53:45  2023-01-17 00:00:00  09:53:45
# 3     2023-01-17 09:54:00  2023-01-17 00:00:00  09:54:00
# 4     2023-01-17 09:54:15  2023-01-17 00:00:00  09:54:15
# ...                   ...                  ...       ...
# 59186 2024-03-12 11:07:25           12/03/2024  11:07:25
# 59187 2024-03-12 11:07:40           12/03/2024  11:07:40
# 59188 2024-03-12 11:07:55           12/03/2024  11:07:55
# 59189 2024-03-12 11:08:10           12/03/2024  11:08:10
# 59190 2024-03-12 11:08:25           12/03/2024  11:08:25
#
#        Temperatura_in_A_[ºC]  Temperatura_out_O2_A_[ºC]  \
# 0                       28.1                       28.9
# 1                       28.2                       28.9
# 2                       28.2                       29.0
# 3                       28.2                       29.0
# 4                       28.2                       29.0
# ...                      ...                        ...
# 59186                    NaN                        NaN
# 59187                   33.7                       43.8
# 59188                   33.6                       43.7
# 59189                   34.2                       43.3
# 59190                   34.3                       43.1
#
#        Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  Tensao_A_[V]  \
# 0                           28.8             0.1           0.0
# 1                           28.8             0.1           0.0
# 2                           28.8             0.1           0.0
# 3                           28.9             0.1           0.0
# 4                           28.9             0.1           0.0
# ...                          ...             ...           ...
# 59186                        NaN             NaN           NaN
# 59187                       42.7             0.2           0.6
# 59188                       42.5             0.3           0.5
# 59189                       42.5             0.3           0.5
# 59190                       42.4             0.3           0.5
#
#        Temperatura_in_B_[ºC]  Temperatura_out_O2_B_[ºC]  \
# 0                       30.7                       29.3
# 1                       30.7                       29.3
# 2                       30.7                       29.3
# 3                       30.8                       29.3
# 4                       30.8                       29.3
# ...                      ...                        ...
# 59186                    NaN                        NaN
# 59187                   36.4                       44.6
# 59188                   35.0                       44.5
# 59189                   35.3                       44.4
# 59190                   35.4                       44.3
#
#        Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  Tensao_B_[V]  PowerSet_[%]  \
# 0                           28.8             0.0           0.0          30.0
# 1                           28.8             0.0           0.0          30.0
# 2                           28.8             0.0           0.0          30.0
# 3                           28.9             0.0           0.0          30.0
# 4                           28.9             0.0           0.0          30.0
# ...                          ...             ...           ...           ...
# 59186                        NaN             NaN           NaN          50.0
# 59187                       42.7             1.2           0.0          50.0
# 59188                       42.5             1.2           0.0          30.0
# 59189                       42.5             1.2           0.0          30.0
# 59190                       42.4             1.2           0.0          30.0
#
#        Pressão_Buffer_[Nm3/h]
# 0                        13.6
# 1                        13.6
# 2                        13.6
# 3                        13.6
# 4                        13.6
# ...                       ...
# 59186                     NaN
# 59187                    14.1
# 59188                    14.1
# 59189                    14.1
# 59190                    14.1
#
# [59191 rows x 15 columns]

# %% [markdown]
# # **TRANSFORMANDO A COLUNA 'Data' NO FORMADO 'DD/MM/AAAA'.**
#
# ---

# %%
# FORMATANDO A COLUNA DE DATA PARA OFORMATO "DD/MM/AAAA".
db['Data'] = pd.to_datetime(db['Data'])
db['Data'] = db['Data'].dt.strftime('%d/%m/%Y')

display(db)
# Out:
#                 Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 0     2023-01-17 09:53:15  17/01/2023  09:53:15                   28.1
# 1     2023-01-17 09:53:30  17/01/2023  09:53:30                   28.2
# 2     2023-01-17 09:53:45  17/01/2023  09:53:45                   28.2
# 3     2023-01-17 09:54:00  17/01/2023  09:54:00                   28.2
# 4     2023-01-17 09:54:15  17/01/2023  09:54:15                   28.2
# ...                   ...         ...       ...                    ...
# 59186 2024-03-12 11:07:25  03/12/2024  11:07:25                    NaN
# 59187 2024-03-12 11:07:40  03/12/2024  11:07:40                   33.7
# 59188 2024-03-12 11:07:55  03/12/2024  11:07:55                   33.6
# 59189 2024-03-12 11:08:10  03/12/2024  11:08:10                   34.2
# 59190 2024-03-12 11:08:25  03/12/2024  11:08:25                   34.3
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 0                           28.9                       28.8             0.1
# 1                           28.9                       28.8             0.1
# 2                           29.0                       28.8             0.1
# 3                           29.0                       28.9             0.1
# 4                           29.0                       28.9             0.1
# ...                          ...                        ...             ...
# 59186                        NaN                        NaN             NaN
# 59187                       43.8                       42.7             0.2
# 59188                       43.7                       42.5             0.3
# 59189                       43.3                       42.5             0.3
# 59190                       43.1                       42.4             0.3
#
#        Tensao_A_[V]  Temperatura_in_B_[ºC]  Temperatura_out_O2_B_[ºC]  \
# 0               0.0                   30.7                       29.3
# 1               0.0                   30.7                       29.3
# 2               0.0                   30.7                       29.3
# 3               0.0                   30.8                       29.3
# 4               0.0                   30.8                       29.3
# ...             ...                    ...                        ...
# 59186           NaN                    NaN                        NaN
# 59187           0.6                   36.4                       44.6
# 59188           0.5                   35.0                       44.5
# 59189           0.5                   35.3                       44.4
# 59190           0.5                   35.4                       44.3
#
#        Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  Tensao_B_[V]  PowerSet_[%]  \
# 0                           28.8             0.0           0.0          30.0
# 1                           28.8             0.0           0.0          30.0
# 2                           28.8             0.0           0.0          30.0
# 3                           28.9             0.0           0.0          30.0
# 4                           28.9             0.0           0.0          30.0
# ...                          ...             ...           ...           ...
# 59186                        NaN             NaN           NaN          50.0
# 59187                       42.7             1.2           0.0          50.0
# 59188                       42.5             1.2           0.0          30.0
# 59189                       42.5             1.2           0.0          30.0
# 59190                       42.4             1.2           0.0          30.0
#
#        Pressão_Buffer_[Nm3/h]
# 0                        13.6
# 1                        13.6
# 2                        13.6
# 3                        13.6
# 4                        13.6
# ...                       ...
# 59186                     NaN
# 59187                    14.1
# 59188                    14.1
# 59189                    14.1
# 59190                    14.1
#
# [59191 rows x 15 columns]

# %% [markdown]
# # **MOSTRANDO OS TIPOS DE DADOS DO 'db'.**
#
# ---

# %%
# TRAZENDO OS TIPOS DE DADOS DA TABELA.
tipos_dados = db.dtypes

# MOSTRANDO/APRESENTANDO OS RESULTADOS.
print(tipos_dados)
# Out:
# Data/Hora                    datetime64[ns]
# Data                                 object
# Hora                                 object
# Temperatura_in_A_[ºC]               float64
# Temperatura_out_O2_A_[ºC]           float64
# Temperatura_out_H2_A_[ºC]           float64
# Corrente_A_[A]                      float64
# Tensao_A_[V]                        float64
# Temperatura_in_B_[ºC]               float64
# Temperatura_out_O2_B_[ºC]           float64
# Temperatura_out_H2_B_[ºC]           float64
# Corrente_B_[A]                      float64
# Tensao_B_[V]                        float64
# PowerSet_[%]                        float64
# Pressão_Buffer_[Nm3/h]              float64
# dtype: object

# %% [markdown]
# # **FILTRANDO A TABELA PARA APENAS 1 DIA EM ESPECÍFICO. O DB DO DIA SERÁ CHAMADO 'db_dia'.**
#
# ---

# %%
# FILTRANDO A TABELA EM UM DIA ESPECÍFICO.
db_dia = db.loc[db['Data/Hora'].dt.date == pd.to_datetime('2023-12-26').date()]

display(db_dia)
# Out:
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55757 2023-12-26 09:22:02.834  26/12/2023  09:22:03                   26.0
# 55758 2023-12-26 09:22:17.834  26/12/2023  09:22:18                   26.0
# 55759 2023-12-26 09:22:32.834  26/12/2023  09:22:33                   26.0
# 55760 2023-12-26 09:22:47.834  26/12/2023  09:22:48                   26.0
# 55761 2023-12-26 09:23:02.834  26/12/2023  09:23:03                   26.0
# ...                       ...         ...       ...                    ...
# 56120 2023-12-26 10:52:47.834  26/12/2023  10:52:48                   35.7
# 56121 2023-12-26 10:53:02.834  26/12/2023  10:53:03                   35.7
# 56122 2023-12-26 10:53:17.834  26/12/2023  10:53:18                   35.7
# 56123 2023-12-26 10:53:32.834  26/12/2023  10:53:33                   35.7
# 56124 2023-12-26 10:53:47.834  26/12/2023  10:53:48                   35.7
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55757                       29.3                       26.1             0.2
# 55758                       27.7                       26.1             0.2
# 55759                       27.2                       26.1             0.1
# 55760                       26.3                       26.1             0.1
# 55761                       25.8                       26.1             0.2
# ...                          ...                        ...             ...
# 56120                       40.1                       39.1             0.2
# 56121                       39.9                       39.0             0.2
# 56122                       39.7                       38.8             0.2
# 56123                       39.4                       38.8             0.2
# 56124                       39.3                       38.7             0.2
#
#        Tensao_A_[V]  Temperatura_in_B_[ºC]  Temperatura_out_O2_B_[ºC]  \
# 55757           0.0                   28.1                       26.5
# 55758           0.0                   28.1                       26.5
# 55759           0.0                   28.1                       26.5
# 55760           0.0                   28.1                       26.5
# 55761           0.0                   28.2                       26.5
# ...             ...                    ...                        ...
# 56120           0.5                   37.5                       41.1
# 56121           0.4                   37.4                       41.1
# 56122           0.4                   37.3                       41.0
# 56123           0.4                   37.3                       40.9
# 56124           0.4                   37.3                       40.8
#
#        Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  Tensao_B_[V]  PowerSet_[%]  \
# 55757                       26.1             0.0           0.0          30.0
# 55758                       26.1             0.0           0.0          30.0
# 55759                       26.1             0.0           0.0          30.0
# 55760                       26.1             0.0           0.0          30.0
# 55761                       26.1             0.0           0.0          30.0
# ...                          ...             ...           ...           ...
# 56120                       39.1             1.5           0.0          30.0
# 56121                       39.0             1.5           0.0          30.0
# 56122                       38.8             1.5           0.0          30.0
# 56123                       38.8             1.5           0.0          30.0
# 56124                       38.7             1.5           0.0          30.0
#
#        Pressão_Buffer_[Nm3/h]
# 55757                    13.7
# 55758                    13.7
# 55759                    13.7
# 55760                    13.7
# 55761                    13.7
# ...                       ...
# 56120                    14.0
# 56121                    14.0
# 56122                    14.0
# 56123                    14.0
# 56124                    14.0
#
# [368 rows x 15 columns]

# %% [markdown]
# # **CRIANDO E FORMATANDO O GRÁFICO DE CORRENTES A E B.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_dia['Data/Hora'], \
            db_dia['Corrente_A_[A]'], \
                label='Corrente A')

plt.plot(db_dia['Data/Hora'], \
            db_dia['Corrente_B_[A]'], \
                label='Corrente B')

# ADICIONANDO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Correntes [A]')

# ADICIONANDO O TÍTULO.
plt.title('Correntes A e B em [A] ao longo do tempo')

# # ADICIONANDO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# INCLINANDO O EIXO X.
# plt.xticks(rotation=45)

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **CRIANDO AS COLUNAS DE POTÊNCIA DE A E DE B.**
#
# ---

# %%
# CALCULANDO A POTÊNCIA DE A.
# db_dia['Potencia_A_[kW]'] = db_dia['Corrente_A_[A]'] * db_dia['Tensao_A_[V]'] / 1000

# TRAZENDO O ÍNDICE DA COLUNA 'Tensao_A_[V]'.
indice_tensao_a = db_dia.columns.get_loc('Tensao_A_[V]')

# INSERINDO A COLUNA 'Potencia_A_[kW]' DEPOIS DA COLUNA 'Tensao_A_[V]'.
db_dia.insert(indice_tensao_a + 1, \
                'Potencia_A_[kW]', \
                    db_dia['Corrente_A_[A]'] * db_dia['Tensao_A_[V]'] / 1000)

# TRAZENDO O ÍNDICE DA COLUNA 'Tensao_B_[V]'.
indice_tensao_B = db_dia.columns.get_loc('Tensao_B_[V]')

# INSERINDO A COLUNA 'Potencia_B_[kW]' DEPOIS DA COLUNA 'Tensao_B_[V]'.
db_dia.insert(indice_tensao_B + 1, \
                'Potencia_B_[kW]', \
                    db_dia['Corrente_B_[A]'] * db_dia['Tensao_B_[V]'] / 1000)

display(db_dia)
# Out:
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55757 2023-12-26 09:22:02.834  26/12/2023  09:22:03                   26.0
# 55758 2023-12-26 09:22:17.834  26/12/2023  09:22:18                   26.0
# 55759 2023-12-26 09:22:32.834  26/12/2023  09:22:33                   26.0
# 55760 2023-12-26 09:22:47.834  26/12/2023  09:22:48                   26.0
# 55761 2023-12-26 09:23:02.834  26/12/2023  09:23:03                   26.0
# ...                       ...         ...       ...                    ...
# 56120 2023-12-26 10:52:47.834  26/12/2023  10:52:48                   35.7
# 56121 2023-12-26 10:53:02.834  26/12/2023  10:53:03                   35.7
# 56122 2023-12-26 10:53:17.834  26/12/2023  10:53:18                   35.7
# 56123 2023-12-26 10:53:32.834  26/12/2023  10:53:33                   35.7
# 56124 2023-12-26 10:53:47.834  26/12/2023  10:53:48                   35.7
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55757                       29.3                       26.1             0.2
# 55758                       27.7                       26.1             0.2
# 55759                       27.2                       26.1             0.1
# 55760                       26.3                       26.1             0.1
# 55761                       25.8                       26.1             0.2
# ...                          ...                        ...             ...
# 56120                       40.1                       39.1             0.2
# 56121                       39.9                       39.0             0.2
# 56122                       39.7                       38.8             0.2
# 56123                       39.4                       38.8             0.2
# 56124                       39.3                       38.7             0.2
#
#        Tensao_A_[V]  Potencia_A_[kW]  Temperatura_in_B_[ºC]  \
# 55757           0.0          0.00000                   28.1
# 55758           0.0          0.00000                   28.1
# 55759           0.0          0.00000                   28.1
# 55760           0.0          0.00000                   28.1
# 55761           0.0          0.00000                   28.2
# ...             ...              ...                    ...
# 56120           0.5          0.00010                   37.5
# 56121           0.4          0.00008                   37.4
# 56122           0.4          0.00008                   37.3
# 56123           0.4          0.00008                   37.3
# 56124           0.4          0.00008                   37.3
#
#        Temperatura_out_O2_B_[ºC]  Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  \
# 55757                       26.5                       26.1             0.0
# 55758                       26.5                       26.1             0.0
# 55759                       26.5                       26.1             0.0
# 55760                       26.5                       26.1             0.0
# 55761                       26.5                       26.1             0.0
# ...                          ...                        ...             ...
# 56120                       41.1                       39.1             1.5
# 56121                       41.1                       39.0             1.5
# 56122                       41.0                       38.8             1.5
# 56123                       40.9                       38.8             1.5
# 56124                       40.8                       38.7             1.5
#
#        Tensao_B_[V]  Potencia_B_[kW]  PowerSet_[%]  Pressão_Buffer_[Nm3/h]
# 55757           0.0              0.0          30.0                    13.7
# 55758           0.0              0.0          30.0                    13.7
# 55759           0.0              0.0          30.0                    13.7
# 55760           0.0              0.0          30.0                    13.7
# 55761           0.0              0.0          30.0                    13.7
# ...             ...              ...           ...                     ...
# 56120           0.0              0.0          30.0                    14.0
# 56121           0.0              0.0          30.0                    14.0
# 56122           0.0              0.0          30.0                    14.0
# 56123           0.0              0.0          30.0                    14.0
# 56124           0.0              0.0          30.0                    14.0
#
# [368 rows x 17 columns]

# %% [markdown]
# # **CRIANDO A COLUNA DE HORAS EM FORMATO DECIMAL.**
#
# ---

# %%
# CRIANDO A COLUNA 'Hora_decimal'.
db_dia['Hora_decimal'] = db_dia['Data/Hora'].dt.hour + \
                                db_dia['Data/Hora'].dt.minute / 60 + \
                                    db_dia['Data/Hora'].dt.second / 3600

display(db_dia)
# Out:
# <ipython-input-8-ab8d1de6ca18>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db_dia['Hora_decimal'] = db_dia['Data/Hora'].dt.hour + \
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55757 2023-12-26 09:22:02.834  26/12/2023  09:22:03                   26.0
# 55758 2023-12-26 09:22:17.834  26/12/2023  09:22:18                   26.0
# 55759 2023-12-26 09:22:32.834  26/12/2023  09:22:33                   26.0
# 55760 2023-12-26 09:22:47.834  26/12/2023  09:22:48                   26.0
# 55761 2023-12-26 09:23:02.834  26/12/2023  09:23:03                   26.0
# ...                       ...         ...       ...                    ...
# 56120 2023-12-26 10:52:47.834  26/12/2023  10:52:48                   35.7
# 56121 2023-12-26 10:53:02.834  26/12/2023  10:53:03                   35.7
# 56122 2023-12-26 10:53:17.834  26/12/2023  10:53:18                   35.7
# 56123 2023-12-26 10:53:32.834  26/12/2023  10:53:33                   35.7
# 56124 2023-12-26 10:53:47.834  26/12/2023  10:53:48                   35.7
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55757                       29.3                       26.1             0.2
# 55758                       27.7                       26.1             0.2
# 55759                       27.2                       26.1             0.1
# 55760                       26.3                       26.1             0.1
# 55761                       25.8                       26.1             0.2
# ...                          ...                        ...             ...
# 56120                       40.1                       39.1             0.2
# 56121                       39.9                       39.0             0.2
# 56122                       39.7                       38.8             0.2
# 56123                       39.4                       38.8             0.2
# 56124                       39.3                       38.7             0.2
#
#        Tensao_A_[V]  Potencia_A_[kW]  Temperatura_in_B_[ºC]  \
# 55757           0.0          0.00000                   28.1
# 55758           0.0          0.00000                   28.1
# 55759           0.0          0.00000                   28.1
# 55760           0.0          0.00000                   28.1
# 55761           0.0          0.00000                   28.2
# ...             ...              ...                    ...
# 56120           0.5          0.00010                   37.5
# 56121           0.4          0.00008                   37.4
# 56122           0.4          0.00008                   37.3
# 56123           0.4          0.00008                   37.3
# 56124           0.4          0.00008                   37.3
#
#        Temperatura_out_O2_B_[ºC]  Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  \
# 55757                       26.5                       26.1             0.0
# 55758                       26.5                       26.1             0.0
# 55759                       26.5                       26.1             0.0
# 55760                       26.5                       26.1             0.0
# 55761                       26.5                       26.1             0.0
# ...                          ...                        ...             ...
# 56120                       41.1                       39.1             1.5
# 56121                       41.1                       39.0             1.5
# 56122                       41.0                       38.8             1.5
# 56123                       40.9                       38.8             1.5
# 56124                       40.8                       38.7             1.5
#
#        Tensao_B_[V]  Potencia_B_[kW]  PowerSet_[%]  Pressão_Buffer_[Nm3/h]  \
# 55757           0.0              0.0          30.0                    13.7
# 55758           0.0              0.0          30.0                    13.7
# 55759           0.0              0.0          30.0                    13.7
# 55760           0.0              0.0          30.0                    13.7
# 55761           0.0              0.0          30.0                    13.7
# ...             ...              ...           ...                     ...
# 56120           0.0              0.0          30.0                    14.0
# 56121           0.0              0.0          30.0                    14.0
# 56122           0.0              0.0          30.0                    14.0
# 56123           0.0              0.0          30.0                    14.0
# 56124           0.0              0.0          30.0                    14.0
#
#        Hora_decimal
# 55757      9.367222
# 55758      9.371389
# 55759      9.375556
# 55760      9.379722
# 55761      9.383889
# ...             ...
# 56120     10.879722
# 56121     10.883889
# 56122     10.888056
# 56123     10.892222
# 56124     10.896389
#
# [368 rows x 18 columns]

# %% [markdown]
# # **GERANDO O GRÁFICO DE POTÊNCIA DE A AO LONGO DO TEMPO E CALCULANDO SUA ENERGIA.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_dia['Hora_decimal'], \
            db_dia['Potencia_A_[kW]'], \
                label='Potência de A')

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potência [kW]')

# ADICIONADNO O TÍTULO.
plt.title('Potência de A em [kW] ao longo do Tempo')

# ADICIONADNO A LEGENDA.
plt.legend()

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **PREENCHENDO A ÁREA SOB O GRÁFICO.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_dia['Data/Hora'], \
            db_dia['Potencia_A_[kW]'], \
                label='Potencia de A')

# PREENCHENDO A ÁREA SOB O GRÁFICO.
plt.fill_between(db_dia['Data/Hora'], \
                    db_dia['Potencia_A_[kW]'], \
                        color='blue', \
                            alpha=0.7)

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potência [kW]')

# ADICIONADNO O TÍTULO.
plt.title('Potência de A em [kW] ao longo do Tempo')

# # ADICIONADNO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **CÁLCULO DA ENERGIA DE A ATRAVÉS DA INTEGRAL.**
#
# ---

# %%
# CALCULANDO A INTEGRAL PELO MÉTODO DO TRAPÉZIO.
integral_PotenciaA = np.trapz(db_dia['Potencia_A_[kW]'], \
                                db_dia['Hora_decimal'])

# FORMATANDO O DADO DA INTEGRAL PARA 3 DÍGITOS.
integral_PotenciaA = round(integral_PotenciaA , 3)

# IMPRIMINDO O RESULTADO.
print("Energia de A:", integral_PotenciaA, "[kJ]")
# Out:
# Energia de A: 11.039 [kJ]

# %% [markdown]
# # **GERANDO O GRÁFICO DE POTÊNCIA DE B AO LONGO DO TEMPO E CALCULANDO SUA ENERGIA.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_dia['Data/Hora'], \
            db_dia['Potencia_B_[kW]'], \
                label='Potência de B')

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potência [kW]')

# ADICIONADNO O TÍTULO.
plt.title('Potência de B em [kW] ao longo do Tempo')

# ADICIONADNO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **PREENCHENDO A ÁREA SOB O GRÁFICO.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_dia['Data/Hora'], \
            db_dia['Potencia_B_[kW]'], \
                label='Potência de B')

# PREENCHENDO A ÁREA SOB O GRÁFICO.
plt.fill_between(db_dia['Data/Hora'], \
                    db_dia['Potencia_B_[kW]'], \
                        color='blue', \
                            alpha=0.7)

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potência kW]')

plt.title('Potência de B em [kW] ao longo do Tempo')

# ADICIONADNO A LEGENDA.
plt.legend()

# INCLINADNO O EIXO X.
plt.xticks(rotation=45)

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **CÁLCULO DA ENERGIA DE B ATRAVÉS DA INTEGRAL.**
#
# ---

# %%
# CALCULANDO A INTEGRAL PELO MÉTODO DO TRAPÉZIO.
integral_PotenciaB = np.trapz(db_dia['Potencia_B_[kW]'], \
                                db_dia['Hora_decimal'])

# FORMATANDO O DADO DA INTEGRAL PARA 3 DÍGITOS.
integral_PotenciaB = round(integral_PotenciaB , 3)

# IMPRIMINDO O RESULTADO.
print("Energia de B:", integral_PotenciaB, "[kJ]")
# Out:
# Energia de B: 10.475 [kJ]

# %% [markdown]
# # **TESTES EM GRÁFICOS.**
#
# ---

# %% [markdown]
# # **GERANDO GRÁFICO DE CORRENTES A E B COM POWERSET AO LONGO DO TEMPO.**
#
# ---

# %% [markdown]
# # **GRÁFICO 1.**
#
# ---

# %%
# CRIANDO A FIGURA.
fig, ax1 = plt.subplots(figsize=(10, 6))

# PLOTANDO OS DADOS PARA O PRIMEIRO EIXO Y (À ESQUERDA).
ax1.plot(db_dia['Data/Hora'], \
            db_dia['Corrente_A_[A]'], \
                label='Corrente A', \
                    color='blue')

plt.plot(db_dia['Data/Hora'], db_dia['Corrente_B_[A]'], \
            label='Corrente B')

ax1.set_xlabel('Data/Hora')

ax1.set_ylabel('Correntes A e B [A]', \
                    color='blue')

ax1.tick_params(axis='y', \
                    labelcolor='blue')

# PLOTANDO OS DADOS PARA O SEGUNDO EIXO Y (À DIREITA).
ax2 = ax1.twinx()

ax2.plot(db_dia['Data/Hora'], \
            db_dia['PowerSet_[%]'], \
                label='PowerSet', \
                    color='red')

ax2.set_ylabel('PowerSet [%]', \
                    color='red')

ax2.tick_params(axis='y', \
                    labelcolor='red')

# ADICIONADNO A LEGENDA.
lines, labels = ax1.get_legend_handles_labels()

lines2, labels2 = ax2.get_legend_handles_labels()

ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# ADICIONADNO O TÍTULO.
plt.title('Correntes A e B em [A] com PowerSet ao longo do tempo')

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **GRÁFICO 2.**
#
# ---

# %%
# CRIANDO A FIGURA.
fig, ax1 = plt.subplots(figsize=(12, 7))

# PLOTANDO OS DADOS E CRIANDO O EIXO Y ESQUERDO.
ax1.plot(db_dia['Data/Hora'], \
            db_dia['Corrente_A_[A]'], \
                label='Corrente A', \
                    color='blue')

ax1.plot(db_dia['Data/Hora'], \
            db_dia['Corrente_B_[A]'], \
                label='Corrente B', \
                    color='green')

ax1.set_xlabel('Horas')

ax1.set_ylabel('Correntes A e B [A]', color='blue')

ax1.tick_params(axis='y', labelcolor='blue')

# PLOTANDO OS DADOS E CRIANDO O 1º EIXO Y DO LADO DIREITO.
ax1_2 = ax1.twinx()

ax1_2.plot(db_dia['Data/Hora'], \
            db_dia['PowerSet_[%]'], \
                label='Power Set', \
                    color='red')

ax1_2.set_ylabel('Power Set [%]', \
                    color='red')

ax1_2.tick_params(axis='y', \
                    labelcolor='red')

# PLOTANDO OS DADOS E CRIANDO O 2º EIXO Y DO LADO DIREITO.
ax1_3 = ax1.twinx()

ax1_3.spines['right'].set_position(('outward', 60))

ax1_3.plot(db_dia['Data/Hora'], \
            db_dia['Tensao_A_[V]'], \
                label='Tensão A', \
                    color='navy')

ax1_3.plot(db_dia['Data/Hora'], \
            db_dia['Tensao_B_[V]'], \
                label='Tensão B', \
                    color='limegreen')

ax1_3.set_ylabel('Tensões de A e B [V]', \
                    color='green')

ax1_3.tick_params(axis='y', \
                    labelcolor='green')

# ADICIONADNDO A LEGENDA.
lines, labels = ax1.get_legend_handles_labels()

lines2, labels2 = ax1_2.get_legend_handles_labels()

lines3, labels3 = ax1_3.get_legend_handles_labels()

ax1.legend(lines + lines3 + lines2, \
                labels + labels3 + labels2, \
                            loc='upper left')   # MUDANDO A ORDEM QUE APARECE OS PARÂMETROS NA LEGENDA.

# COLOCANDO O TÍTULO DO GRÁFICO.
plt.title('Parâmetros de Energia com PowerSet ao longo do Tempo')

# EDITANDO O EIXO X.
plt.xticks(rotation=90)

ax1.set_xticks(db_dia['Data/Hora'][::100])  # EXIBE APENAS OS 100º TICK PARA EVISTAR SOBREPOSIÇÃO.

# ax1.set_xticklabels(db_dia['HORA'][::100].dt.strftime('%Y-%m-%d %H:%M:%S'))

ax1.set_xticklabels(db_dia['Data/Hora'][::100].dt.strftime('%d/%m/%Y \n %H:%M'))

# MOSTRANDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **FILTRANDO AGORA PELO POWERSET SER IGUAL OU MAIOR QUE 70%.**
#
# ---

# %%
ps_entrada = input('Digite o PowerSet de produção de H2: ')

ps_entrada = float(ps_entrada)

db_ps = db_dia.loc[db_dia['PowerSet_[%]'] >= ps_entrada]

display(db_ps)
# Out:
# Digite o PowerSet de produção de H2: 70
#                     Data/Hora        Data      Hora  Temperatura_in_A_[ºC]  \
# 55910 2023-12-26 10:00:17.834  26/12/2023  10:00:18                   31.4
# 55911 2023-12-26 10:00:32.834  26/12/2023  10:00:33                   31.1
# 55912 2023-12-26 10:00:47.834  26/12/2023  10:00:48                   30.7
# 55913 2023-12-26 10:01:02.834  26/12/2023  10:01:03                   30.3
# 55914 2023-12-26 10:01:17.834  26/12/2023  10:01:18                   30.3
# ...                       ...         ...       ...                    ...
# 56050 2023-12-26 10:35:17.834  26/12/2023  10:35:18                   37.3
# 56051 2023-12-26 10:35:32.834  26/12/2023  10:35:33                   36.1
# 56052 2023-12-26 10:35:47.834  26/12/2023  10:35:48                   37.2
# 56053 2023-12-26 10:36:02.834  26/12/2023  10:36:03                   37.3
# 56054 2023-12-26 10:36:17.834  26/12/2023  10:36:18                   35.9
#
#        Temperatura_out_O2_A_[ºC]  Temperatura_out_H2_A_[ºC]  Corrente_A_[A]  \
# 55910                       34.9                       35.2            96.7
# 55911                       35.0                       35.5            93.0
# 55912                       35.7                       35.7           105.4
# 55913                       35.6                       36.0           101.3
# 55914                       36.0                       36.3           128.4
# ...                          ...                        ...             ...
# 56050                       46.9                       44.3           109.1
# 56051                       46.6                       44.0           115.1
# 56052                       47.1                       44.2           132.8
# 56053                       47.1                       44.4           130.0
# 56054                       47.0                       44.4           120.2
#
#        Tensao_A_[V]  Potencia_A_[kW]  Temperatura_in_B_[ºC]  \
# 55910         129.4         12.51298                   34.1
# 55911         130.7         12.15510                   33.6
# 55912         130.7         13.77578                   33.3
# 55913         130.8         13.25004                   33.0
# 55914         130.8         16.79472                   32.9
# ...             ...              ...                    ...
# 56050         130.0         14.18300                   40.0
# 56051         129.9         14.95149                   39.0
# 56052         129.9         17.25072                   39.8
# 56053         129.9         16.88700                   40.0
# 56054         129.9         15.61398                   38.6
#
#        Temperatura_out_O2_B_[ºC]  Temperatura_out_H2_B_[ºC]  Corrente_B_[A]  \
# 55910                       35.8                       35.2           104.4
# 55911                       35.9                       35.5           114.3
# 55912                       36.2                       35.7           118.2
# 55913                       36.5                       36.0           106.1
# 55914                       36.6                       36.3           123.0
# ...                          ...                        ...             ...
# 56050                       45.2                       44.3           111.0
# 56051                       45.3                       44.0           103.2
# 56052                       45.4                       44.2           133.3
# 56053                       45.5                       44.4           118.4
# 56054                       45.6                       44.4            94.4
#
#        Tensao_B_[V]  Potencia_B_[kW]  PowerSet_[%]  Pressão_Buffer_[Nm3/h]  \
# 55910         120.6         12.59064          70.0                    13.7
# 55911         122.6         14.01318          70.0                    13.7
# 55912         122.6         14.49132          70.0                    13.7
# 55913         122.7         13.01847          70.0                    13.7
# 55914         122.9         15.11670          70.0                    13.8
# ...             ...              ...           ...                     ...
# 56050         121.4         13.47540          70.0                    14.0
# 56051         121.3         12.51816          70.0                    13.9
# 56052         121.3         16.16929          70.0                    13.8
# 56053         121.4         14.37376          70.0                    13.9
# 56054         121.3         11.45072          70.0                    13.9
#
#        Hora_decimal
# 55910     10.004722
# 55911     10.008889
# 55912     10.013056
# 55913     10.017222
# 55914     10.021389
# ...             ...
# 56050     10.588056
# 56051     10.592222
# 56052     10.596389
# 56053     10.600556
# 56054     10.604722
#
# [145 rows x 18 columns]

# %% [markdown]
# # **GERANDO GRÁFICO LIMITADO PELO POWERSET.**
#
# ---

# %%
# CRIANDO A FIGURA.
fig, ax1 = plt.subplots(figsize=(12, 7))

# PLOTANDO OS DADOS E CRIANDO O EIXO Y ESQUERDO.
ax1.plot(db_ps['Data/Hora'], \
            db_ps['Corrente_A_[A]'], \
                label='Corrente A', \
                    color='blue')

ax1.plot(db_ps['Data/Hora'], \
            db_ps['Corrente_B_[A]'], \
                label='Corrente B', \
                    color='green')

ax1.set_xlabel('Horas')

ax1.set_ylabel('Correntes A e B [A]', color='blue')

ax1.tick_params(axis='y', labelcolor='blue')

# PLOTANDO OS DADOS E CRIANDO O 1º EIXO Y DO LADO DIREITO.
ax1_2 = ax1.twinx()

ax1_2.plot(db_ps['Data/Hora'], \
            db_ps['PowerSet_[%]'], \
                label='Power Set', \
                    color='red')

ax1_2.set_ylabel('Power Set [%]', \
                    color='red')

ax1_2.tick_params(axis='y', \
                    labelcolor='red')

# PLOTANDO OS DADOS E CRIANDO O 2º EIXO Y DO LADO DIREITO.
ax1_3 = ax1.twinx()

ax1_3.spines['right'].set_position(('outward', 60))

ax1_3.plot(db_ps['Data/Hora'], \
            db_ps['Tensao_A_[V]'], \
                label='Tensão A', \
                    color='navy')

ax1_3.plot(db_ps['Data/Hora'], \
            db_ps['Tensao_B_[V]'], \
                label='Tensão B', \
                    color='limegreen')

ax1_3.set_ylabel('Tensões de A e B [V]', \
                    color='green')

ax1_3.tick_params(axis='y', \
                    labelcolor='green')

# ADICIONADNDO A LEGENDA.
lines, labels = ax1.get_legend_handles_labels()

lines2, labels2 = ax1_2.get_legend_handles_labels()

lines3, labels3 = ax1_3.get_legend_handles_labels()

ax1.legend(lines + lines3 + lines2, \
                labels + labels3 + labels2, \
                            loc='upper left')   # MUDANDO A ORDEM QUE APARECE OS PARÂMETROS NA LEGENDA.

# COLOCANDO O TÍTULO DO GRÁFICO.
plt.title('Parâmetros de Energia com PowerSet maior ou igual a 70% ao longo do Tempo')

# EDITANDO O EIXO X.
plt.xticks(rotation=90)

ax1.set_xticks(db_ps['Data/Hora'][::100])  # EXIBE APENAS OS 100º TICK PARA EVISTAR SOBREPOSIÇÃO.

# ax1.set_xticklabels(db_dia['HORA'][::100].dt.strftime('%Y-%m-%d %H:%M:%S'))

ax1.set_xticklabels(db_ps['Data/Hora'][::100].dt.strftime('%d/%m/%Y \n %H:%M'))

# MOSTRANDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **GERANDO GRÁFICO DE POTÊNCIAS DE A E DE B LIMITADO PELO POWERSET.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps['Data/Hora'], \
            db_ps['Potencia_A_[kW]'], \
                label='Potência de A')

plt.plot(db_ps['Data/Hora'], \
            db_ps['Potencia_B_[kW]'], \
                label='Potência de B')

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potências [kW]')

plt.title('Potências de A e de B em [kW] ao Longo do Tempo')

# ADICIONADNO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %% [markdown]
# # **GRÁFICOS E CÁLCULOS DE ENERGIA DE A E B SEPARADAMENTE LIMITADO PELO POWERSET.**
#
# ---

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps['Data/Hora'], \
            db_ps['Potencia_A_[kW]'], \
                label='Potência de A')

# PREENCHENDO A ÁREA SOB O GRÁFICO.
plt.fill_between(db_ps['Data/Hora'], \
                    db_ps['Potencia_A_[kW]'], \
                        color='blue', \
                            alpha=0.7)

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potências [kW]')

plt.title('Potência de A em [kW] ao Longo do Tempo')

# ADICIONADNO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %%
# CALCULANDO A INTEGRAL PELO MÉTODO DO TRAPÉZIO.
Energia_A = np.trapz(db_ps['Potencia_A_[kW]'], \
                                db_ps['Hora_decimal'])

# FORMATANDO O DADO DA INTEGRAL PARA 3 DÍGITOS.
Energia_A = round(Energia_A , 3)

# IMPRIMINDO O RESULTADO.
print("Energia de A:", Energia_A, "[kJ]")
# Out:
# Energia de A: 8.976 [kJ]

# %%
# CRIANDO A FIGURA.
plt.figure(figsize=(10, 6))

# PLOTANDO OS DADOS DO GRÁFICO.
plt.plot(db_ps['Data/Hora'], \
            db_ps['Potencia_B_[kW]'], \
                label='Potência de B')

# PREENCHENDO A ÁREA SOB O GRÁFICO.
plt.fill_between(db_ps['Data/Hora'], \
                    db_ps['Potencia_B_[kW]'], \
                        color='blue', \
                            alpha=0.7)

# ADICIONADNO OS EIXOS.
plt.xlabel('Horas')

plt.ylabel('Potências [kW]')

plt.title('Potência de B em [kW] ao Longo do Tempo')

# ADICIONADNO A LEGENDA.
plt.legend()

# FORMATANDO O EIXO X.
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%H:%M:%S'))

# EXIBINDO O GRÁFICO.
plt.tight_layout()

plt.show()

# %%
# CALCULANDO A INTEGRAL PELO MÉTODO DO TRAPÉZIO.
Energia_B = np.trapz(db_ps['Potencia_B_[kW]'], \
                                db_ps['Hora_decimal'])

# FORMATANDO O DADO DA INTEGRAL PARA 3 DÍGITOS.
Energia_B = round(Energia_B , 3)

# IMPRIMINDO O RESULTADO.
print("Energia de B:", Energia_B, "[kJ]")
# Out:
# Energia de B: 8.553 [kJ]

# %% [markdown]
# # **TOTAL DE ENERGIA.**
#
# ---

# %%
Energia_Total = Energia_A + Energia_B
print("Quantidade Total de Energia em [kWh]: ", Energia_Total)
# Out:
# Quantidade Total de Energia em [kWh]:  17.529000000000003
